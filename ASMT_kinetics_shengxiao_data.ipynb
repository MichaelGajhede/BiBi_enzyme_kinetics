# %% [markdown]
# <a href="https://colab.research.google.com/github/MichaelGajhede/BiBi_enzyme_kinetics/blob/main/ASMT_kinetics_shengxiao_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Shengxiao data in csv to dataframe
import pandas as pd

# Define a function that takes a list of file names as input
def read_triplicate_data(filename):
  from google.colab import drive
  drive.mount('/content/drive')
  # Open the CSV file
  file = '/content/drive/MyDrive/' + filename
  open(file, 'r', newline='')

  # Initialize an empty data frame
  #df = pd.DataFrame()
  # Loop through the file names
  df = pd.read_csv(file, sep =';', index_col=0, header=0).T
  # Append the data frame to the main data frame
  # Return the result data frame
  #df.columns = df.iloc[0]
  #df.drop(df.index[5]
  return df

df = read_triplicate_data('BiBi_sequential/ASMT_kin_Shengxiao_round_3_2_mixed.csv')
# Out:
# Mounted at /content/drive

# %%
df
# Out:
#               Conc NAS uM  10 uM SAM  30 uM SAM  60 uM SAM  90 uM SAM  \
# SAM uM                NaN     10.000     30.000     60.000     90.000
# 20 uM NAS            20.0  10456.830  16661.960  21097.160  21393.710
# 20 uM NAS.1          20.0  10130.160  16073.390  23722.690  22141.190
# 20 uM NAS.2          20.0  10986.870  16796.830  21666.290  20692.900
# 50 uM NAS            50.0  13276.210  23178.060  18503.610  27524.650
# 50 uM NAS.1          50.0  12453.030  22247.490  30189.960  28581.840
# 50 uM NAS.2          50.0  14279.330  22680.380  25417.370  27359.000
# 100uM SAM           100.0  16962.930  24447.550  26046.430  29269.230
# 100uM NAS           100.0  16466.160  25384.660  31793.850  25624.630
# 100uM NAS.1         100.0  16451.970  25490.760  30692.610  28227.100
# 300 uM NAS          300.0  14448.260  21146.820  19722.660  19265.860
# 300 uM NAS.1        300.0  14430.490  21717.960  20562.070  22668.390
# 300 uM NAS.2        300.0  14008.690  22984.760  19928.630  19573.920
# 600uM NAS           600.0  12730.540  10456.565  13843.540  10821.200
# 600uM NAS.1         600.0  12746.330  12826.497  13793.640   9740.835
# 600uM NAS.2         600.0  11990.030  12719.284  15288.680   9158.854
# 900uM NAS           900.0   9641.915  11842.641   9999.346   8754.937
# 900uM NAS.1         900.0   9355.515  10079.895  11290.840   9871.364
# 900uM NAS.2         900.0  10193.020   8284.629  10474.980   9796.912
#
#               140 uM SAM  200 uM SAM
# SAM uM           140.000     200.000
# 20 uM NAS      17614.650   25985.870
# 20 uM NAS.1    22765.590   24497.430
# 20 uM NAS.2    20656.560   22593.390
# 50 uM NAS      32501.640   29290.030
# 50 uM NAS.1    30825.620   27922.820
# 50 uM NAS.2    30872.310   30067.940
# 100uM SAM      25772.150   28054.240
# 100uM NAS      31284.080   26504.280
# 100uM NAS.1    30024.440   28921.080
# 300 uM NAS     21189.760   17525.090
# 300 uM NAS.1   19401.270   12920.940
# 300 uM NAS.2   18996.710   15343.770
# 600uM NAS       8458.382   12479.990
# 600uM NAS.1    11849.680    8452.469
# 600uM NAS.2     8507.352   10112.360
# 900uM NAS       5870.440    8100.808
# 900uM NAS.1     6882.795    6949.386
# 900uM NAS.2     8533.240    6538.671

# %%
# group by NAS concentrations and average
grouped = df.groupby(df.columns[0])
areas_averaged = grouped.mean()
areas_averaged.round(1)
# Out:
#              10 uM SAM  30 uM SAM  60 uM SAM  90 uM SAM  140 uM SAM  \
# Conc NAS uM
# 20.0           10524.6    16510.7    22162.0    21409.3     20345.6
# 50.0           13336.2    22702.0    24703.6    27821.8     31399.9
# 100.0          16627.0    25107.7    29511.0    27707.0     29026.9
# 300.0          14295.8    21949.8    20071.1    20502.7     19862.6
# 600.0          12489.0    12000.8    14308.6     9907.0      9605.1
# 900.0           9730.2    10069.1    10588.4     9474.4      7095.5
#
#              200 uM SAM
# Conc NAS uM
# 20.0            24358.9
# 50.0            29093.6
# 100.0           27826.5
# 300.0           15263.3
# 600.0           10348.3
# 900.0            7196.3

# %%
#Calculate standard deviations
esds = grouped.std()
esds.round(1)
# Out:
#              10 uM SAM  30 uM SAM  60 uM SAM  90 uM SAM  140 uM SAM  \
# Conc NAS uM
# 20.0             432.4      384.7     1381.2      724.3      2589.5
# 50.0             914.6      465.7     5875.8      663.4       954.5
# 100.0            291.0      574.1     3050.5     1877.1      2888.2
# 300.0            248.8      940.7      437.5     1881.8      1167.0
# 600.0            432.2     1338.4      849.1      843.5      1944.0
# 900.0            425.7     1779.0      653.2      624.2      1344.1
#
#              200 uM SAM
# Conc NAS uM
# 20.0             1700.5
# 50.0             1086.0
# 100.0            1224.4
# 300.0            2303.1
# 600.0            2024.1
# 900.0             809.8

# %%
# conversion between area and nM/min: Divide area by 22 from standard curve and assay time 15 min
# convert to uM by dividing by 1000 also correct for dilution to stop reaction volume increase from 25 uL to 83 uL

velocities = areas_averaged/22/15/1000/25*83
velocities.round(4)
# Out:
#              10 uM SAM  30 uM SAM  60 uM SAM  90 uM SAM  140 uM SAM  \
# Conc NAS uM
# 20.0            0.1059     0.1661     0.2230     0.2154      0.2047
# 50.0            0.1342     0.2284     0.2485     0.2799      0.3159
# 100.0           0.1673     0.2526     0.2969     0.2787      0.2920
# 300.0           0.1438     0.2208     0.2019     0.2063      0.1998
# 600.0           0.1256     0.1207     0.1440     0.0997      0.0966
# 900.0           0.0979     0.1013     0.1065     0.0953      0.0714
#
#              200 uM SAM
# Conc NAS uM
# 20.0             0.2451
# 50.0             0.2927
# 100.0            0.2800
# 300.0            0.1536
# 600.0            0.1041
# 900.0            0.0724

# %%
# calculate velocity esds
velocities_esds = esds/22/15/1000/25*83
velocities_esds.round(4)
# Out:
#              10 uM SAM  30 uM SAM  60 uM SAM  90 uM SAM  140 uM SAM  \
# Conc NAS uM
# 20.0            0.0043     0.0039     0.0139     0.0073      0.0261
# 50.0            0.0092     0.0047     0.0591     0.0067      0.0096
# 100.0           0.0029     0.0058     0.0307     0.0189      0.0291
# 300.0           0.0025     0.0095     0.0044     0.0189      0.0117
# 600.0           0.0043     0.0135     0.0085     0.0085      0.0196
# 900.0           0.0043     0.0179     0.0066     0.0063      0.0135
#
#              200 uM SAM
# Conc NAS uM
# 20.0             0.0171
# 50.0             0.0109
# 100.0            0.0123
# 300.0            0.0232
# 600.0            0.0204
# 900.0            0.0081

# %%
# change velocities dataframe column names to have SAM conc's only as float

import numpy as np

c_NAS = np.array([20.,50.,100.,300.,600.,900.])
c_SAM = np.array([10., 30., 60., 90., 140., 200.])

V = velocities.copy()
V_esds = velocities_esds.copy()
# column headings changed to concentrations as float values
V.columns = c_SAM
V_esds.columns = c_SAM

V.columns
# Out:
# Index([10.0, 30.0, 60.0, 90.0, 140.0, 200.0], dtype='float64')

# %%
# take out subset of data from V and V_esds, default use all


V.drop(V.tail(0).index,inplace = True)
V_esds.drop(V.tail(0).index,inplace = True)

x_SAM = V.columns
y_NAS = V.index

X,Y = np.meshgrid(x_SAM,y_NAS)

Z = V.values

xdata = np.column_stack((X.flatten(), Y.flatten()))
zdata = V.values.flatten()
V
# Out:
#                 10.0      30.0      60.0      90.0      140.0     200.0
# Conc NAS uM
# 20.0         0.105884  0.166108  0.222964  0.215390  0.204689  0.245065
# 50.0         0.134170  0.228396  0.248534  0.279904  0.315902  0.292699
# 100.0        0.167278  0.252598  0.296898  0.278749  0.292028  0.279952
# 300.0        0.143825  0.220829  0.201928  0.206270  0.199830  0.153558
# 600.0        0.125647  0.120735  0.143953  0.099670  0.096634  0.104110
# 900.0        0.097891  0.101301  0.106526  0.095318  0.071385  0.072399

# %% [markdown]
# # SAM concentration on X-axis, NAS on Y. SAM as A in BiBi models NAS is B!! SAM vil then be first substrate in ordered sequential BiBi reactions, NAS second

# %% [markdown]
# # Define standard Michaelis Menten function

# %%
def michaelis_menten(substrate, v_max, k_m):
  """
  This function defines the Michaelis-Menten equation.

  Args:
      substrate: The concentration of the substrate.
      v_max: The maximum reaction velocity.
      k_m: The Michaelis constant.

  Returns:
      The reaction velocity.
  """
  return (v_max * substrate) / (k_m + substrate)

# %%
# Plot for fixed NAS conc and fit MM equation - subplot edition

import pandas as pd
import matplotlib.pyplot as plt
import os
from scipy.optimize import curve_fit

#more x values for curve plotting
x_SAM_fit = np.arange(10,200,.1)


# Define the number of rows and columns for subplots (assuming equal columns)
# Use transposed matrix for fixed NAS
n_rows = int(np.ceil(len(V.T.columns) / 3))  # adjust 3 for desired columns per row
n_cols = 3  # adjust for desired columns per row

# Create the figure and subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(12, 6))  # adjust figsize as needed

# Loop through each column and plot in a subplot
for i, col in enumerate(V.T.columns):

    row = i // n_cols
    colo = i % n_cols  # calculate subplot indexes

    # Get the data for the current column
    data = V.T[col]
    col_array = data.to_numpy()

    # Choose your preferred plot type (example: histogram)
    axes[row, colo].plot(data)
    axes[row, colo].errorbar(x = data.index, y = data.values, yerr = V_esds.T[col], capsize = 5, ecolor = None)
    optimizedParameters, pcov = curve_fit(michaelis_menten, x_SAM, col_array)
    print(col, ' uM NAS Vmax, KMapp : ', optimizedParameters)
    axes[row, colo].plot(x_SAM_fit, michaelis_menten(x_SAM_fit, *optimizedParameters), label=optimizedParameters, color = '0')



    # Customize each subplot (labels, title, etc.)
    axes[row, colo].set_title(str(col) +  ' uM NAS ' + 'KMapp =' + str(int(optimizedParameters[1])))
    axes[row, colo].set_xlabel('concentration uM SAM' )
    axes[row, colo].set_ylabel("v in uM/min")

# Adjust spacing and layout if needed
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# 20.0  uM NAS Vmax, KMapp :  [ 0.24886918 13.29242311]
# 50.0  uM NAS Vmax, KMapp :  [ 0.32510046 14.09207322]
# 100.0  uM NAS Vmax, KMapp :  [0.30712511 7.36979527]
# 300.0  uM NAS Vmax, KMapp :  [0.19991216 2.42596093]
# 600.0  uM NAS Vmax, KMapp :  [ 0.10990682 -1.47889161]
# 900.0  uM NAS Vmax, KMapp :  [ 0.08659226 -1.51273946]
# <ipython-input-10-c2cf0510659e>:35: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   axes[row, colo].plot(x_SAM_fit, michaelis_menten(x_SAM_fit, *optimizedParameters), label=optimizedParameters, color = '0')
# <ipython-input-10-c2cf0510659e>:35: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   axes[row, colo].plot(x_SAM_fit, michaelis_menten(x_SAM_fit, *optimizedParameters), label=optimizedParameters, color = '0')
# <ipython-input-10-c2cf0510659e>:35: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   axes[row, colo].plot(x_SAM_fit, michaelis_menten(x_SAM_fit, *optimizedParameters), label=optimizedParameters, color = '0')
# <ipython-input-10-c2cf0510659e>:35: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   axes[row, colo].plot(x_SAM_fit, michaelis_menten(x_SAM_fit, *optimizedParameters), label=optimizedParameters, color = '0')
# <ipython-input-10-c2cf0510659e>:35: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   axes[row, colo].plot(x_SAM_fit, michaelis_menten(x_SAM_fit, *optimizedParameters), label=optimizedParameters, color = '0')
# <ipython-input-10-c2cf0510659e>:35: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   axes[row, colo].plot(x_SAM_fit, michaelis_menten(x_SAM_fit, *optimizedParameters), label=optimizedParameters, color = '0')

# %% [markdown]
# # Define substrate inhibited Michaelis Menten function to describe the data
# ![picture](https://drive.google.com/uc?id=1Q0_nAvHA1_3KK8W0yfOk-lDI8OyjPrT7)

# %%
import numpy as np
from scipy.optimize import curve_fit

def michaelis_menten_substrate_inhibition(substrate, v_max, k_m, k_i):
  """
  This function defines the Michaelis-Menten equation.

  Args:
      substrate: The concentration of the substrate.
      v_max: The maximum reaction velocity.
      k_m: The Michaelis constant.

  Returns:
      The reaction velocity.
  """
  return (v_max * substrate) / (k_m + substrate + substrate*substrate/k_i)

# %%
# Plot for fixed NAS conc and fit MM equation with substrate inhibition - subplot edition

import pandas as pd
import matplotlib.pyplot as plt
import os
from scipy.optimize import curve_fit

#more x values for curve plotting
x_SAM_fit = np.arange(10,200,.1)


# Define the number of rows and columns for subplots (assuming equal columns)
# Use transposed matrix for fixed NAS
n_rows = int(np.ceil(len(V.T.columns) / 3))  # adjust 3 for desired columns per row
n_cols = 3  # adjust for desired columns per row

# Create the figure and subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(12, 6))  # adjust figsize as needed

# Loop through each column and plot in a subplot
for i, col in enumerate(V.T.columns):

    row = i // n_cols
    colo = i % n_cols  # calculate subplot indexes

    # Get the data for the current column
    data = V.T[col]
    col_array = data.to_numpy()

    # Choose your preferred plot type (example: histogram)
    axes[row, colo].plot(data)
    axes[row, colo].errorbar(x = data.index, y = data.values, yerr = V_esds.T[col], capsize = 5, ecolor = None)
    optimizedParameters, pcov = curve_fit(michaelis_menten_substrate_inhibition, x_SAM, col_array)
    print(col, ' uM NAS Vmax, KMapp : ', optimizedParameters)
    axes[row, colo].plot(x_SAM_fit, michaelis_menten_substrate_inhibition(x_SAM_fit, *optimizedParameters), label=optimizedParameters, color = '0')



    # Customize each subplot (labels, title, etc.)
    axes[row, colo].set_title(str(col) +  ' uM NAS ' + 'KMapp =' + str(int(optimizedParameters[1]))+ ' Kiapp =' + str(int(optimizedParameters[2])))
    axes[row, colo].set_xlabel('concentration uM SAM' )
    axes[row, colo].set_ylabel("v in uM/min")

# Adjust spacing and layout if needed
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# 20.0  uM NAS Vmax, KMapp :  [2.48877182e-01 1.32934700e+01 4.66837082e+06]
# 50.0  uM NAS Vmax, KMapp :  [3.28550636e-01 1.44602911e+01 1.54723509e+04]
# 100.0  uM NAS Vmax, KMapp :  [3.58470507e-01 1.12515078e+01 8.75972818e+02]
# 300.0  uM NAS Vmax, KMapp :  [  0.31441517  10.9442887  224.64697459]
# 600.0  uM NAS Vmax, KMapp :  [1.41178940e-01 1.04865900e+00 4.21850483e+02]
# 900.0  uM NAS Vmax, KMapp :  [1.33114547e-01 3.29556864e+00 2.19217783e+02]
# <ipython-input-12-05e2e13fb9de>:35: MatplotlibDeprecationWarning: Passing label as a length 3 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   axes[row, colo].plot(x_SAM_fit, michaelis_menten_substrate_inhibition(x_SAM_fit, *optimizedParameters), label=optimizedParameters, color = '0')
# <ipython-input-12-05e2e13fb9de>:35: MatplotlibDeprecationWarning: Passing label as a length 3 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   axes[row, colo].plot(x_SAM_fit, michaelis_menten_substrate_inhibition(x_SAM_fit, *optimizedParameters), label=optimizedParameters, color = '0')
# <ipython-input-12-05e2e13fb9de>:35: MatplotlibDeprecationWarning: Passing label as a length 3 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   axes[row, colo].plot(x_SAM_fit, michaelis_menten_substrate_inhibition(x_SAM_fit, *optimizedParameters), label=optimizedParameters, color = '0')
# <ipython-input-12-05e2e13fb9de>:35: MatplotlibDeprecationWarning: Passing label as a length 3 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   axes[row, colo].plot(x_SAM_fit, michaelis_menten_substrate_inhibition(x_SAM_fit, *optimizedParameters), label=optimizedParameters, color = '0')
# <ipython-input-12-05e2e13fb9de>:35: MatplotlibDeprecationWarning: Passing label as a length 3 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   axes[row, colo].plot(x_SAM_fit, michaelis_menten_substrate_inhibition(x_SAM_fit, *optimizedParameters), label=optimizedParameters, color = '0')
# <ipython-input-12-05e2e13fb9de>:35: MatplotlibDeprecationWarning: Passing label as a length 3 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   axes[row, colo].plot(x_SAM_fit, michaelis_menten_substrate_inhibition(x_SAM_fit, *optimizedParameters), label=optimizedParameters, color = '0')

# %%
# Plot for fixed SAM conc and fit MM equation - subplot edition

import pandas as pd
import matplotlib.pyplot as plt
import os
from scipy.optimize import curve_fit

#more x values for curve plotting
y_NAS_fit = np.arange(20,900,.1)


# Define the number of rows and columns for subplots (assuming equal columns)
# Use transposed matrix for fixed NAS
n_rows = int(np.ceil(len(V.columns) / 3))  # adjust 3 for desired columns per row
n_cols = 3  # adjust for desired columns per row

# Create the figure and subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(12, 6))  # adjust figsize as needed

# Loop through each column and plot in a subplot
for i, col in enumerate(V.columns):

    row = i // n_cols
    colo = i % n_cols  # calculate subplot indexes

    # Get the data for the current column
    data = V[col]
    col_array = data.to_numpy()

    # Choose your preferred plot type (example: histogram)
    axes[row, colo].plot(data)
    axes[row, colo].errorbar(x = data.index, y = data.values, yerr = V_esds[col], capsize = 5, ecolor = None)
    optimizedParameters, pcov = curve_fit(michaelis_menten, y_NAS, col_array)
    print(col, ' uM SAM Vmax, KMapp : ', optimizedParameters)
    axes[row, colo].plot(y_NAS_fit, michaelis_menten(y_NAS_fit, *optimizedParameters), label=optimizedParameters, color = '0')



    # Customize each subplot (labels, title, etc.)
    axes[row, colo].set_title(str(col) +  ' uM SAM ' + 'KMapp =' + str(int(optimizedParameters[1])))
    axes[row, colo].set_xlabel('concentration uM NAS' )
    axes[row, colo].set_ylabel("v in uM/min")

# Adjust spacing and layout if needed
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# 10.0  uM SAM Vmax, KMapp :  [0.13394104 2.7325092 ]
# 30.0  uM SAM Vmax, KMapp :  [ 0.17688993 -1.77176922]
# 60.0  uM SAM Vmax, KMapp :  [ 0.18847028 -4.66700616]
# 90.0  uM SAM Vmax, KMapp :  [ 0.1788667  -5.43393697]
# 140.0  uM SAM Vmax, KMapp :  [ 0.18018125 -5.31960569]
# 200.0  uM SAM Vmax, KMapp :  [ 0.16603105 -7.78600526]
# <ipython-input-13-1dc4fca4b4e7>:35: MatplotlibDeprecationWarning: Passing label as a length 2 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   axes[row, colo].plot(y_NAS_fit, michaelis_menten(y_NAS_fit, *optimizedParameters), label=optimizedParameters, color = '0')

# %%
# Plot for fixed SAM conc and fit MM equation - subplot edition

import pandas as pd
import matplotlib.pyplot as plt
import os
from scipy.optimize import curve_fit

#more x values for curve plotting
y_NAS_fit = np.arange(20,900,.1)


# Define the number of rows and columns for subplots (assuming equal columns)
# Use transposed matrix for fixed NAS
n_rows = int(np.ceil(len(V.columns) / 3))  # adjust 3 for desired columns per row
n_cols = 3  # adjust for desired columns per row

# Create the figure and subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(12, 6))  # adjust figsize as needed

# Loop through each column and plot in a subplot
for i, col in enumerate(V.columns):

    row = i // n_cols
    colo = i % n_cols  # calculate subplot indexes

    # Get the data for the current column
    data = V[col]
    col_array = data.to_numpy()

    # Choose your preferred plot type (example: histogram)
    axes[row, colo].plot(data)
    axes[row, colo].errorbar(x = data.index, y = data.values, yerr = V_esds[col], capsize = 5, ecolor = None)
    optimizedParameters, pcov = curve_fit(michaelis_menten_substrate_inhibition, y_NAS, col_array)
    print(col, ' uM SAM Vmax, KMapp : ', optimizedParameters)
    axes[row, colo].plot(y_NAS_fit, michaelis_menten_substrate_inhibition(y_NAS_fit, *optimizedParameters), label=optimizedParameters, color = '0')



    # Customize each subplot (labels, title, etc.)
    axes[row, colo].set_title(str(col) +  ' uM SAM ' + 'KMapp =' + str(int(optimizedParameters[1]))+ ' Kiapp =' + str(int(optimizedParameters[2])))
    axes[row, colo].set_xlabel('concentration uM NAS' )
    axes[row, colo].set_ylabel("v in uM/min")

# Adjust spacing and layout if needed
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# 10.0  uM SAM Vmax, KMapp :  [2.12169355e-01 2.10590859e+01 8.30520485e+02]
# 30.0  uM SAM Vmax, KMapp :  [  0.42839546  32.33504444 289.94102544]
# 60.0  uM SAM Vmax, KMapp :  [  0.40356828  16.52627316 334.95165441]
# 90.0  uM SAM Vmax, KMapp :  [  0.4862784   23.64196808 202.60066762]
# <ipython-input-14-2a4bc27f7447>:35: MatplotlibDeprecationWarning: Passing label as a length 3 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   axes[row, colo].plot(y_NAS_fit, michaelis_menten_substrate_inhibition(y_NAS_fit, *optimizedParameters), label=optimizedParameters, color = '0')
# 140.0  uM SAM Vmax, KMapp :  [  0.75244313  48.23282989 101.32160101]
# 200.0  uM SAM Vmax, KMapp :  [  0.52138505  19.92342963 140.71909384]

# %% [markdown]
# # Conclusion from analysis wth one fixed substrate concentration:
#
# In this concentration range ASMT undergo substrate inhibition. Most pronounced by NAS but also by SAM. Model for inhibition:
#
#
# This is very different from the clearly ordered sequential reaction  that is observed for Cathecol O-methyl transferase in the Lotta paper with SAM entering first and NAS last:
#
# Lotta, T., Vidgren, J., Tilgmann, C., Ulmanen, I., Melén, K., Julkunen, I., & Taskinen, J. (1995). Kinetics of Human Soluble and Membrane-Bound Catechol O-Methyltransferase: A Revised Mechanism and Description of the Thermolabile Variant of the Enzyme. Biochemistry, 34(13), 4202–4210. https://doi.org/10.1021/bi00013a008
#
# Then again ASMT is a dimer with a very occluded active site whereas COMT is moonomeric with a relatively open active site.

# %% [markdown]
# # Now for 2D analysis
#
# Bisubstrate reactions can sequential or ping-pong. Ping-pong would involve that SAM delivered a methyl group, left the enzyme ans then NAS would come and react with the protein bound methyl group. From the crystal structure with the ternary complex 4a6c I think we can rule that out.
# Sequential reactions can be either ordered as show in fig. 1
#
# ![picture](https://drive.google.com/uc?id=1WuEcGPH00CQM7L2Eivc4Oed3s5TIFjEj)
#
#
#
#
# For the random mechanism (fig. 3) :
#
# ![picture](https://drive.google.com/uc?id=1O0xGxA6dXDYqd7YwHS34M44RhqHXIyII)
#
#
#
# It is importent to realize that rate curves from both models will be hyperbolic in both dimensions. If maxima occur it can be explained by substrate inhibition (fig. 4):
#
# ![picture](https://drive.google.com/uc?id=1OqtGLjJL2lf_cdBdUIs4hHCN0V3cEdMW)

# %% [markdown]
# # Now let's take a look at Shengxiao's data in surface representation

# %%
# Surface plot of velocities Shengxiao data

import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10, 10)

# Create a 3D axes
fig = plt.figure()
ax = plt.axes(projection='3d')


# Plot the surface plot
ax.plot_surface(X, Y, Z, cmap=plt.cm.cividis)
ax.view_init(elev=30, azim=-22, roll=0)
ax.set_xlabel('SAM uM')
ax.set_ylabel('NAS uM')
ax.set_zlabel('v')
plt.title('Surface plot of ASMT velocities Shengxiao data 2')
plt.show()

# %% [markdown]
# # BiBi sequential models to describe the data:

# %%
#MM 2 substrate sequential ordered rate function
def BiBi(X,  Vmax, Ks_A, K_AB):

  C_A = np.hsplit(X, len(X[0]))[0]
  C_B = np.hsplit(X, len(X[0]))[1]

  nom = C_A * C_B * Vmax
  den = Ks_A * K_AB + K_AB * C_A + C_A * C_B

  Vi = nom/den
  return Vi.flatten()

# %%
#MM 2 substrate inhibition model A sequential ordered rate function from :

'''
Vallejos-Baccelliere, G., Kaufman, S. B., González-Lebrero, R. M., Castro-Fernandez, V., & Guixé, V. (2022).
Characterisation of kinetics, substrate inhibition and product activation by
AMP of bifunctional ADP-dependent glucokinase/phosphofructokinase from Methanococcus maripaludis.
FEBS Journal, 289(23), 7519–7536. https://doi.org/10.1111/febs.16557
'''

def BiBi_substrate_B_inhibition(X,  Vmax, Ks_A, K_AB, Ki_B):

  C_A = np.hsplit(X, len(X[0]))[0]
  C_B = np.hsplit(X, len(X[0]))[1]


  nom = C_A * C_B * Vmax
  den = Ks_A * K_AB + K_AB * C_A + C_A * C_B + C_B * C_B/Ki_B

  Vi = nom/den
  return Vi.flatten()

# %%
#MM 2 substrate inhibition model C sequential ordered rate function two dead-end complexes

'''
Vallejos-Baccelliere, G., Kaufman, S. B., González-Lebrero, R. M., Castro-Fernandez, V., & Guixé, V. (2022).
Characterisation of kinetics, substrate inhibition and product activation by
AMP of bifunctional ADP-dependent glucokinase/phosphofructokinase from Methanococcus maripaludis.
FEBS Journal, 289(23), 7519–7536. https://doi.org/10.1111/febs.16557
'''

def BiBi_substrate_AB_inhibition(X,  Vmax, Ks_A, K_AB, Ki_B, Ki_A):

  C_A = np.hsplit(X, len(X[0]))[0]
  C_B = np.hsplit(X, len(X[0]))[1]


  nom = C_A * C_B * Vmax
  den = Ks_A * K_AB + K_AB * C_A + C_A * C_B + C_A * C_B * C_B/Ki_A + C_B * C_B/Ki_B

  Vi = nom/den
  return Vi.flatten()

# %%
#MM 2 substrate sequential random ordered rate function
def BiBi_random(X,  Vmax, Ks_A, Ks_B, K_AB, K_BA):

  C_A = np.hsplit(X, len(X[0]))[0]
  C_B = np.hsplit(X, len(X[0]))[1]

  nom = C_A * C_B * Vmax
  den = Ks_A * K_AB + K_AB * C_A + K_BA * C_B + C_A * C_B

  Vi = nom/den
  return Vi.flatten()

# %%
#MM 2 substrate sequential random ordered rate function with substrate B inhibition via formation of an unproductive EB2 complex
def BiBi_random_B_inhibition(X,  Vmax, Ks_A, Ks_B, K_AB, K_BA, Ki_B2):

  C_A = np.hsplit(X, len(X[0]))[0]
  C_B = np.hsplit(X, len(X[0]))[1]

  nom = C_A * C_B * Vmax
  den = Ks_A * K_AB + K_AB * C_A + K_BA * C_B + C_A * C_B + C_B * C_B / Ki_B2

  Vi = nom/den
  return Vi.flatten()

# %%
#MM 2 substrate sequential random ordered rate function with substrate B inhibition via formation of an unproductive EA2 and EB2 complexes
def BiBi_random_AB_inhibition(X,  Vmax, Ks_A, K_AB, K_BA, Ki_A2, Ki_B2):

  C_A = np.hsplit(X, len(X[0]))[0]
  C_B = np.hsplit(X, len(X[0]))[1]

  nom = C_A * C_B * Vmax
  den = Ks_A * K_AB + K_AB * C_A + K_BA * C_B + C_A * C_B + C_B * C_B / Ki_B2 + C_A * C_A / Ki_A2

  Vi = nom/den
  return Vi.flatten()

# %%
#MM 2 substrate sequential random ordered rate function with substrate B inhibition via formation of an unproductive EA2 and EB2 complexes
# try for better convergence and one parameter less. Also this model implies that a second B molecule binds to EAB and forms unproductive EAB2 complex.
def BiBi_random_AB_inhibition_2(X,  A, K_AB, K_BA, Ki_EAB2, Ki_B2):

  C_A = np.hsplit(X, len(X[0]))[0]
  C_B = np.hsplit(X, len(X[0]))[1]
  Vmax = .4

  nom = C_A * C_B * Vmax
  den = A + K_AB * C_A + K_BA * C_B + C_A * C_B + C_B * C_B / Ki_B2 + C_B * C_B * C_A / Ki_EAB2

  Vi = nom/den
  return Vi.flatten()

# %%
#MM 2 substrate sequential random ordered rate function with substrate B inhibition via formation of an unproductive EA2 and EB2 complexes
# try for better convergence and one parameter less. Also this model implies that a second B molecule binds to EAB and forms unproductive EAB2 complex.
# fix K_AB and K_BA
def BiBi_random_AB_inhibition_3(X,  A, Ki_EAB2, Ki_B2):

  C_A = np.hsplit(X, len(X[0]))[0]
  C_B = np.hsplit(X, len(X[0]))[1]
  Vmax = .4
  K_AB = 10
  K_BA = 20

  nom = C_A * C_B * Vmax
  den = A + K_AB * C_A + K_BA * C_B + C_A * C_B + C_B * C_B / Ki_B2 + C_B * C_B * C_A / Ki_EAB2

  Vi = nom/den
  return Vi.flatten()

# %%
#MM 2 substrate sequential random ordered rate function with substrate B inhibition via formation of an unproductive EA2 and EB2 complexes
# try for better convergence and one parameter less. Also this model implies that a second B molecule binds to EAB and forms unproductive EAB2 complex.
# Exclude EB2 complex
def BiBi_random_AB_inhibition_4(X,  A, K_AB, K_BA, Ki_EAB2):

  C_A = np.hsplit(X, len(X[0]))[0]
  C_B = np.hsplit(X, len(X[0]))[1]
  Vmax = .4

  nom = C_A * C_B * Vmax
  den = A + K_AB * C_A + K_BA * C_B + C_A * C_B  + C_B * C_B * C_A / Ki_EAB2

  Vi = nom/den
  return Vi.flatten()

# %% [markdown]
# # Now use scipy curve_fit to determine kinetic parameters

# %%
# Import curve_fit from scipy.optimize and determine substrate inhibition model parameters from the Shengxiao data 2
import os
from scipy.optimize import curve_fit

#print(xdata)

popt, pcov = curve_fit(BiBi_substrate_B_inhibition, xdata, zdata)
variance = [pcov[0][0], pcov[1][1], pcov[2][2], pcov[3][3]]
np.set_printoptions(precision=4)
print('Model parameters: ', popt)
print('ESD             : ', np.sqrt(variance))
print('Overfit estimate: ', np.linalg.cond(pcov))
# Out:
# Model parameters:  [2.7161e-01 9.3969e+03 2.1939e-02 9.3688e+00]
# ESD             :  [3.6422e-02 2.0375e+06 4.8424e+00 3.9877e+00]
# Overfit estimate:  3.5517552528189284e+16

# %%
# Plot velocities from curve_fit determined parameters allejos-Baccelliere model A

# Create a 3D axes
fig = plt.figure()
ax = plt.axes(projection='3d')

#X,Y = np.meshgrid(x_SAM, x_NAS)

Vmax = 0.27
Ks_A = 9124
K_AB = 0.025
Ki_B = 9.37


Z = np.reshape(BiBi_substrate_B_inhibition(xdata,  Vmax, Ks_A, K_AB , Ki_B), (6,6))


# Plot the surface plot
ax.plot_surface(X, Y, Z, cmap=plt.cm.cividis)
ax.view_init(elev=30, azim=-22, roll=0)
ax.set_xlabel('SAM')
ax.set_ylabel('NAS')
ax.set_zlabel('v')
plt.title('Surface plot of ASMT BiBi model')
plt.show()

# %% [markdown]
# This is the only model that converges with scipy. Ir implies the formation of an unproducrive EAB' complex along with the productive EAB complex. It is, however, evident that inhibition depends on both substrate concentrations.

# %%
# Import curve_fit from scipy.optimize and determine substrate inhibition model parameters from the Shengxiao data 2
import os
from scipy.optimize import curve_fit

#print(xdata)

popt, pcov = curve_fit(BiBi_substrate_AB_inhibition, xdata, zdata, p0=[.27, 600.0, 10.0, 10, 100], maxfev = 30000)
variance = [pcov[0][0], pcov[1][1], pcov[2][2], pcov[3][3]]
np.set_printoptions(precision=4)
print('Model parameters: ', popt)
print('ESD             : ', np.sqrt(variance))
print('Overfit estimate: ', np.linalg.cond(pcov))
# Out:
# Model parameters:  [ 3.6755e-01 -3.5124e+07 -2.3445e-05  4.6014e+06  3.2212e+02]
# ESD             :  [3.2169e-02 3.9983e+12 2.6882e+00 1.6461e+11]
# Overfit estimate:  5.193022906490844e+32

# %%
# Plot velocities from curve_fit determined parameters allejos-Baccelliere model A

# Create a 3D axes
fig = plt.figure()
ax = plt.axes(projection='3d')

#X,Y = np.meshgrid(x_SAM, x_NAS)

Vmax = 0.27
Ks_A = 10
K_AB = 30
Ki_B = 40
Ki_A = 500



Z = np.reshape(BiBi_substrate_AB_inhibition(xdata,  Vmax, Ks_A, K_AB , Ki_B, Ki_A), (6,6))


# Plot the surface plot
ax.plot_surface(X, Y, Z, cmap=plt.cm.cividis)
ax.view_init(elev=30, azim=-22, roll=0)
ax.set_xlabel('SAM')
ax.set_ylabel('NAS')
ax.set_zlabel('v')
plt.title('Surface plot of ASMT BiBi model')
plt.show()

# %% [markdown]
# From just playing around with the parameters a quite good qualitative fit can be obtained with an ordered sequential reaction . Vmax too low though.

# %%
# Import curve_fit from scipy.optimize and determine random model parameters from the Shengxiao data 2
import os
from scipy.optimize import curve_fit

print(xdata)

popt, pcov = curve_fit(BiBi_random_AB_inhibition_4, xdata, zdata, maxfev = 30000, bounds=(0, 100000))
variance = [pcov[0][0], pcov[1][1], pcov[2][2], pcov[3][3]]
#variance = [pcov[0][0], pcov[1][1], pcov[2][2]]
np.set_printoptions(precision=4)

Vmax = 0.3
E_t = 0.4 # uM
kcat = Vmax/E_t

print('Model parameters: ', popt)
print('ESD             : ', np.sqrt(variance))
K_AB =  popt[1]
K_BA =  popt[2]
Ks_A = popt[0]/K_AB
K_AB2 = popt[3]
Ks_B = K_AB/K_BA * Ks_A
print('kcat: ', kcat, 'K_AB: ', K_AB, ' K_BA: ', K_BA, ' Ks_A: ', Ks_A, ' Ks_B: ', Ks_B, ' K_AB2: ', K_AB2)
print('Overfit estimate: ', np.linalg.cond(pcov))

# Plot velocities from curve_fit determined parameters allejos-Baccelliere model A

# Create a 3D axes
fig = plt.figure()
ax = plt.axes(projection='3d')

Z = np.reshape(BiBi_random_AB_inhibition_4(xdata,  *popt), (6,6))

# Plot the surface plot
ax.plot_surface(X, Y, Z, cmap=plt.cm.cividis)
ax.view_init(elev=30, azim=-22, roll=0)
ax.set_xlabel('SAM')
ax.set_ylabel('NAS')
ax.set_zlabel('v')
plt.title('Surface plot of ASMT BiBi model')
plt.show()
# Out:
# [[ 10.  20.]
#  [ 30.  20.]
#  [ 60.  20.]
#  [ 90.  20.]
#  [140.  20.]
#  [200.  20.]
#  [ 10.  50.]
#  [ 30.  50.]
#  [ 60.  50.]
#  [ 90.  50.]
#  [140.  50.]
#  [200.  50.]
#  [ 10. 100.]
#  [ 30. 100.]
#  [ 60. 100.]
#  [ 90. 100.]
#  [140. 100.]
#  [200. 100.]
#  [ 10. 300.]
#  [ 30. 300.]
#  [ 60. 300.]
#  [ 90. 300.]
#  [140. 300.]
#  [200. 300.]
#  [ 10. 600.]
#  [ 30. 600.]
#  [ 60. 600.]
#  [ 90. 600.]
#  [140. 600.]
#  [200. 600.]
#  [ 10. 900.]
#  [ 30. 900.]
#  [ 60. 900.]
#  [ 90. 900.]
#  [140. 900.]
#  [200. 900.]]
# Model parameters:  [588.0498   7.326    1.3313 285.3561]
# ESD             :  [161.2645   1.8901   2.4059  19.9503]
# kcat:  0.7499999999999999 K_AB:  7.326022066779415  K_BA:  1.3313192081165985  Ks_A:  80.26863895302476  Ks_B:  441.70460146227157  K_AB2:  285.3561081414516
# Overfit estimate:  23081.96126775025

# %%
def create_2d_numpy_array_with_fixed_value(num_rows, fixed_value, other_values=None):
    """
    Creates a 2D NumPy array where one column has a fixed value.

    Args:
        num_rows: The number of rows in the 2D array.
        fixed_value: The value that will be fixed in one column.
        other_values: (Optional) A list or NumPy array of values for the other
            column. If None, defaults to an array of zeros. If a list is
            provided, its length should be equal to num_rows. If a NumPy array
            is provided, its shape should be (num_rows,).

    Returns:
        A 2D NumPy array.

    Raises:
        ValueError: If other_values is provided and its length is not
            equal to num_rows.
    """
    if other_values is not None:
        if isinstance(other_values, list) and len(other_values) != num_rows:
            raise ValueError("Length of other_values must be equal to num_rows")
        elif isinstance(other_values, np.ndarray) and other_values.shape != (num_rows,):
            raise ValueError("Shape of other_values must be (num_rows,)")

    # Initialize the array with the fixed value in the first column
    two_d_array = np.empty((num_rows, 2))  # Create an empty array
    two_d_array[:, 0] = fixed_value  # Set the first column to fixed_value

    if other_values is None:
        two_d_array[:, 1] = 0  # Default the second column to 0
    else:
        two_d_array[:, 1] = other_values  # Assign the provided values

    return two_d_array

# %%
# Plot for fixed SAM conc and fit BiBi_random_AB_inhibition_4 equation - subplot edition

import pandas as pd
import matplotlib.pyplot as plt
import os
from scipy.optimize import curve_fit

#more x values for curve plotting
y_NAS_fit = np.arange(20,900,.1)


# Define the number of rows and columns for subplots (assuming equal columns)
# Use transposed matrix for fixed NAS
n_rows = int(np.ceil(len(V.columns) / 3))  # adjust 3 for desired columns per row
n_cols = 3  # adjust for desired columns per row

# Create the figure and subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(12, 6))  # adjust figsize as needed

# Loop through each column and plot in a subplot
for i, col in enumerate(V.columns):

    row = i // n_cols
    colo = i % n_cols  # calculate subplot indexes

    # Get the data for the current column
    data = V[col]
    col_array = data.to_numpy()
    # create 2D nympy array with dimensions number of SAM conventrations x length of y_NAS_fit for the 2D plots
    plot_x = create_2d_numpy_array_with_fixed_value(len(y_NAS_fit), c_SAM[i], other_values=y_NAS_fit)

    # Choose your preferred plot type (example: histogram)
    axes[row, colo].plot(data)
    axes[row, colo].errorbar(x = data.index, y = data.values, yerr = V_esds[col], capsize = 5, ecolor = None)
    #optimizedParameters, pcov = curve_fit(michaelis_menten_substrate_inhibition, y_NAS, col_array)
    #print(col, ' uM SAM Vmax, KMapp : ', optimizedParameters)
    axes[row, colo].plot(y_NAS_fit, BiBi_random_AB_inhibition_4(plot_x, *popt), label=optimizedParameters, color = '0')



    # Customize each subplot (labels, title, etc.)
    axes[row, colo].set_title(str(col) +  ' uM SAM ' + 'KM =' + str(int(optimizedParameters[1]))+ ' Ki =' + str(int(optimizedParameters[2])))
    axes[row, colo].set_xlabel('concentration uM NAS' )
    axes[row, colo].set_ylabel("v in uM/min")

# Adjust spacing and layout if needed
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-48-b3fa7ee9a326>:37: MatplotlibDeprecationWarning: Passing label as a length 3 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   axes[row, colo].plot(y_NAS_fit, BiBi_random_AB_inhibition_4(plot_x, *popt), label=optimizedParameters, color = '0')

# %% [markdown]
# # Conclusion:
#
# A random sequential model (BiBi_random_AB_inhibition_4) where SAM (molecule A) most often binds first to form EA complex followed by bindins of NAS (molecule B) in unproductive mode and one more NAS in productive mode gives physically realistic kinetic parameters and explains Sherngxiao's data reasonably well.
#
# ![picture](https://drive.google.com/uc?id=1yipj1uTNEaCh-1G1i0FlfDRvrdmGMipO)
#
#
# ![picture](https://drive.google.com/uc?id=1LrObrQXpGEE88pyhaZbMEa98J9jRrtEp)
#
# Rate lav derivation:

# %% [markdown]
# Calculation of Species concentrations:
#
# ![picture](https://drive.google.com/uc?id=1rGUTrnvb5bT-hAjmUwt0TeUvBFdzDBRs)

# %%
# Calculate species concentrations at initial rate equilibrium conditions

A = c_SAM
B = c_NAS[:, np.newaxis] # B now 2D

a1 = A/Ks_A
a2 = B/Ks_B
a3 = A*B/Ks_A/K_AB
a4 = A*B*B/K_AB/Ks_A/K_AB2
a5 = 1 + a1 + a2 + a3 + a4

E = E_t/a5
EA = a1 * E
EB = a2 * E
EAB = a3 * E
EAB2 = a4 * E

# Number of rows and columns for the subplot grid
rows = E.shape[0]
cols = 6

# Create a figure and subplots
fig, axes = plt.subplots(rows, cols, figsize=(20, 20))  # Adjust figure size as needed
fig.suptitle('Pie plots of ASMT species composition Shengxiao data 2 with {:.2f} uM total enzyme concentration and kcat {:.2f} per minute'.format(E_t, kcat))

# Loop through each row and create a pie chart in a subplot
for row_index in range(rows):
  for col_index in range(cols):
    # Extract elements from the corresponding array
    elements = [E[row_index, col_index], EA[row_index, col_index], EB[row_index, col_index], EAB[row_index, col_index], EAB2[row_index, col_index]]

    # Create labels
    labels = ["E", "EA", "EB", "EAB", "EAB2"]

    # Create the pie chart in the current subplot
    axes[row_index, col_index].pie(elements, labels=labels, autopct="%1.1f%%")
    axes[row_index, col_index].set_title("SAM {} uM - NAS {} uM ".format(A.item(row_index), B.item(col_index)))

    # Remove ticks and labels for cleaner subplots
    axes[row_index, col_index].axis('equal')  # Equal aspect ratio for circle
    axes[row_index, col_index].set_xticks([])
    axes[row_index, col_index].set_yticks([])

# Adjust spacing and show the plot
#fig.tight_layout()
plt.show()

# %% [markdown]
# Conclusions:
# 1. As EB is always low for low substrate concentrations, the reaction can here essentially be describes as a sequential ordered reaction with SAM binding first.
# 2. At the lowest substrate concentrations the prominent species are E, EA and EAB. So in terms of which binding pocket to target, all 3 are possible.
# 3. At high SAM and NAS concentrations EAB2 becomes dominant. However in terms of cellular concentrations these is probably highly unrealistic.
# 4. kcat is very similar with that from Lotta et al COMT work. They use COMT concentrations around 30 nM and get Vmax of 37 nM/min giving a kcat around 1 min-1 as we do.
